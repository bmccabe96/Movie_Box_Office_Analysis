# %% [markdown]
# # Anaylzing how Release Month affects Sales

# %% [markdown]
# ## Does the Month of the year really affect sales?

# %%
import pandas as pd
import numpy as np #Importing Necessary Libraries

# %%
df=pd.read_csv('Mojo_Plus_IMDB_Data.csv')
df.head() #importing dataframe and looking at first 5 rows
# Out:
#    Unnamed: 0                                 Title       Gross  Max_Theaters  \
# 0           0  The Woman in Black 2: Angel of Death  26501323.0          2602
# 1           1            The Search for General Tso     54275.0            13
# 2           2          The Taking of Tiger Mountain    228984.0            13
# 3           3                         Li'l Quinquin      7192.0             2
# 4           4                         Trace Amounts     80735.0             7
#
#    Opening_Weekend_Theaters  Opening_Weekend_Gross  \
# 0                      2602             15027415.0
# 1                         2                 9336.0
# 2                         7                50621.0
# 3                         1                 3204.0
# 4                         0                    0.0
#
#    Opening_Weekend_Percent_of_Gross                Distributor  \
# 0                              56.7           Relativity Media
# 1                              17.2                  IFC Films
# 2                              22.1  Well Go USA Entertainment
# 3                              44.5                Kino Lorber
# 4                               0.0                 GathrFilms
#
#                                               Genres Rating  ...  \
# 0                    ['Drama', 'Horror', 'Thriller']  PG-13  ...
# 1    ['Comedy', 'Documentary', 'History', 'Mystery']    NaN  ...
# 2  ['Action', 'Adventure', 'Biography', 'History'...    NaN  ...
# 3                     ['Comedy', 'Crime', 'Mystery']    NaN  ...
# 4   ['Adventure', 'Documentary', 'Drama', 'History']    NaN  ...
#
#    Unnamed: 0_y     genre_ids        id  original_language  \
# 0       14310.0  [53, 27, 18]  288158.0                 en
# 1       12399.0          [99]  261041.0                 en
# 2           NaN           NaN       NaN                NaN
# 3           NaN           NaN       NaN                NaN
# 4           NaN           NaN       NaN                NaN
#
#                          original_title  popularity release_date  \
# 0  The Woman in Black 2: Angel of Death      10.240   2015-01-02
# 1            The Search for General Tso       1.404   2014-04-20
# 2                                   NaN         NaN          NaN
# 3                                   NaN         NaN          NaN
# 4                                   NaN         NaN          NaN
#
#                                   title  vote_average vote_count
# 0  The Woman in Black 2: Angel of Death           5.1      627.0
# 1            The Search for General Tso           6.7       31.0
# 2                                   NaN           NaN        NaN
# 3                                   NaN           NaN        NaN
# 4                                   NaN           NaN        NaN
#
# [5 rows x 23 columns]

# %%
df.columns #column list
# Out:
# Index(['Unnamed: 0', 'Title', 'Gross', 'Max_Theaters',
#        'Opening_Weekend_Theaters', 'Opening_Weekend_Gross',
#        'Opening_Weekend_Percent_of_Gross', 'Distributor', 'Genres', 'Rating',
#        'Runtime', 'Date', 'title_lowercase', 'Unnamed: 0_y', 'genre_ids', 'id',
#        'original_language', 'original_title', 'popularity', 'release_date',
#        'title', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
df.drop('Unnamed: 0',axis=1,inplace=True) #dropping non useful column
df.head()
# Out:
#                                   Title       Gross  Max_Theaters  \
# 0  The Woman in Black 2: Angel of Death  26501323.0          2602
# 1            The Search for General Tso     54275.0            13
# 2          The Taking of Tiger Mountain    228984.0            13
# 3                         Li'l Quinquin      7192.0             2
# 4                         Trace Amounts     80735.0             7
#
#    Opening_Weekend_Theaters  Opening_Weekend_Gross  \
# 0                      2602             15027415.0
# 1                         2                 9336.0
# 2                         7                50621.0
# 3                         1                 3204.0
# 4                         0                    0.0
#
#    Opening_Weekend_Percent_of_Gross                Distributor  \
# 0                              56.7           Relativity Media
# 1                              17.2                  IFC Films
# 2                              22.1  Well Go USA Entertainment
# 3                              44.5                Kino Lorber
# 4                               0.0                 GathrFilms
#
#                                               Genres Rating  Runtime  ...  \
# 0                    ['Drama', 'Horror', 'Thriller']  PG-13       98  ...
# 1    ['Comedy', 'Documentary', 'History', 'Mystery']    NaN       71  ...
# 2  ['Action', 'Adventure', 'Biography', 'History'...    NaN      141  ...
# 3                     ['Comedy', 'Crime', 'Mystery']    NaN      206  ...
# 4   ['Adventure', 'Documentary', 'Drama', 'History']    NaN       97  ...
#
#   Unnamed: 0_y     genre_ids        id original_language  \
# 0      14310.0  [53, 27, 18]  288158.0                en
# 1      12399.0          [99]  261041.0                en
# 2          NaN           NaN       NaN               NaN
# 3          NaN           NaN       NaN               NaN
# 4          NaN           NaN       NaN               NaN
#
#                          original_title popularity release_date  \
# 0  The Woman in Black 2: Angel of Death     10.240   2015-01-02
# 1            The Search for General Tso      1.404   2014-04-20
# 2                                   NaN        NaN          NaN
# 3                                   NaN        NaN          NaN
# 4                                   NaN        NaN          NaN
#
#                                   title vote_average vote_count
# 0  The Woman in Black 2: Angel of Death          5.1      627.0
# 1            The Search for General Tso          6.7       31.0
# 2                                   NaN          NaN        NaN
# 3                                   NaN          NaN        NaN
# 4                                   NaN          NaN        NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# ## So now we will begin  determining which month or months are the best to release a movie.

# %% [markdown]
# ## To do this, I will be adding a Year and a Month column. Then, I will do a groupby to extract gross sales data by month and year.

# %%
df.Date.tail() #checking the formatting of the date column
# Out:
# 4534    2020-08-14
# 4535    2020-08-14
# 4536    2020-08-14
# 4537    2020-08-14
# 4538    2020-08-14
# Name: Date, dtype: object

# %%
df['Year']=df.Date.apply(lambda x:x[0:4])#extracting year from date and adding to Year
df.Year=pd.to_numeric(df.Year)           #column
df.Year
# Out:
# 0       2015
# 1       2015
# 2       2015
# 3       2015
# 4       2015
#         ...
# 4534    2020
# 4535    2020
# 4536    2020
# 4537    2020
# 4538    2020
# Name: Year, Length: 4539, dtype: int64

# %%
df['Month']=df.Date.apply(lambda x:x[5:7])#extracting month from date column and adding to
df.Month=df.Month.astype('int')           #Month column
df.Month
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 4534    8
# 4535    8
# 4536    8
# 4537    8
# 4538    8
# Name: Month, Length: 4539, dtype: int64

# %%
df.columns #confirming columns were added
# Out:
# Index(['Title', 'Gross', 'Max_Theaters', 'Opening_Weekend_Theaters',
#        'Opening_Weekend_Gross', 'Opening_Weekend_Percent_of_Gross',
#        'Distributor', 'Genres', 'Rating', 'Runtime', 'Date', 'title_lowercase',
#        'Unnamed: 0_y', 'genre_ids', 'id', 'original_language',
#        'original_title', 'popularity', 'release_date', 'title', 'vote_average',
#        'vote_count', 'Year', 'Month'],
#       dtype='object')

# %%
df.groupby(['Year','Month']).median() #checking statistics after grouping by Year and Month
# Out:
#                Gross  Max_Theaters  Opening_Weekend_Theaters  \
# Year Month
# 2015 1       86098.5          15.5                      11.0
#      2      378329.0          40.5                       5.0
#      3      176391.0          29.0                       4.0
#      4      129784.0          25.0                       6.0
#      5      103536.0          20.0                       2.0
# ...              ...           ...                       ...
# 2020 4       19920.5           3.0                       3.0
#      5       65713.0          10.5                       2.0
#      6       86419.5          33.0                      28.0
#      7      164000.0          72.0                      68.0
#      8       46746.0          40.5                      40.5
#
#             Opening_Weekend_Gross  Opening_Weekend_Percent_of_Gross  Runtime  \
# Year Month
# 2015 1                    20150.0                             40.70     99.5
#      2                    40503.5                             28.20    101.5
#      3                    24963.5                             28.25     99.0
#      4                    19206.0                             30.70    102.0
#      5                    14471.0                             13.50    100.0
# ...                           ...                               ...      ...
# 2020 4                     5516.5                             24.45    110.0
#      5                      767.5                              2.50     96.5
#      6                    26125.5                             23.30     96.0
#      7                   140000.0                              0.00    106.0
#      8                    27239.0                            100.00     93.5
#
#             Unnamed: 0_y        id  popularity  vote_average  vote_count
# Year Month
# 2015 1           14252.0  252838.0      6.2060          6.40       126.0
#      2           14270.0  252718.5      8.1250          6.10       396.0
#      3           14342.5  259786.0      5.1045          6.40        64.0
#      4           14414.5  262307.0      5.7320          6.30        83.5
#      5           14408.0  270886.0      5.8870          6.20        77.0
# ...                  ...       ...         ...           ...         ...
# 2020 4               NaN       NaN         NaN           NaN         NaN
#      5               NaN       NaN         NaN           NaN         NaN
#      6           11147.0  371017.5      0.6000          3.75         1.5
#      7             747.0   39240.0      2.3770          5.50        10.0
#      8           21436.0  480970.0      0.6000         10.00         1.0
#
# [68 rows x 11 columns]

# %%
y_2015=df.groupby(['Year','Month']).median()['Gross'][2015]#Extracting Gross Sales Data 
x_2015=y_2015.index                                          #Month by Month and Year by Year
y_2016=df.groupby(['Year','Month']).median()['Gross'][2016]
x_2016=y_2016.index
y_2017=df.groupby(['Year','Month']).median()['Gross'][2017]
x_2017=y_2017.index
y_2018=df.groupby(['Year','Month']).median()['Gross'][2018]
x_2018=y_2018.index
y_2019=df.groupby(['Year','Month']).median()['Gross'][2019]
x_2019=y_2019.index
y_2020=df.groupby(['Year','Month']).median()['Gross'][2020]
x_2020=y_2020.index

# %%
import matplotlib.pyplot as plt #making distinct plot for each year's median sales data
# %matplotlib inline 
plt.style.use('seaborn')
#each plot breaks down the sales data month by month

fig,ax=plt.subplots(3,2, figsize=(25,25))
ax[0][0].bar(x_2015,y_2015,color='red')
ax[0][0].set_xlabel('Month')
ax[0][0].set_ylabel('Median Gross Sales ($ in millions)')
ax[0][0].set_title('2015 Median Gross Sales per Month')
ax[0][1].bar(x_2016,y_2016,color='green')
ax[0][1].set_xlabel('Month')
ax[0][1].set_ylabel('Gross Sales ($ in millions)')
ax[0][1].set_title('2016 Median Gross Sales per Month')
ax[1][0].bar(x_2017,y_2017,color='blue')
ax[1][0].set_xlabel('Month')
ax[1][0].set_ylabel('Gross Sales ($ in millions)')
ax[1][0].set_title('2017 Median Gross Sales per Month')
ax[1][1].bar(x_2018,y_2018,color='yellow')
ax[1][1].set_xlabel('Month')
ax[1][1].set_ylabel('Gross Sales ($)')
ax[1][1].set_title('2018 Median Gross Sales per Month')
ax[2][0].bar(x_2019,y_2019,color='black')
ax[2][0].set_xlabel('Month')
ax[2][0].set_ylabel('Gross Sales ($)')
ax[2][0].set_title('2019 Median Gross Sales per Month')
ax[2][1].bar(x_2020,y_2020,color='magenta')
ax[2][1].set_xlabel('Month')
ax[2][1].set_ylabel('Gross Sales ($)')
ax[2][1].set_title('2020 Median Gross Sales per Month')
fig.savefig('2015-2020 Monthly Median Gross Box Officw Sales',bbox_inches='tight')

# %%
df.groupby(['Year','Month']).median()['Gross'].sort_values(ascending=False).head(20)
#Confirming through sorting which month's are best and comparing with visualizations
# Out:
# Year  Month
# 2017  12       3226443.0
# 2016  11       1738477.0
#       12       1485167.5
# 2015  12       1110707.0
# 2018  12        727119.0
# 2017  2         671045.5
# 2015  11        538460.0
# 2019  12        425332.0
# 2015  2         378329.0
# 2019  8         353777.5
#       2         351019.0
# 2020  1         313104.0
# 2017  11        305206.5
# 2016  10        292227.5
# 2019  10        265673.0
# 2018  7         258507.0
# 2015  10        249083.0
# 2018  9         245253.5
# 2017  10        235786.5
# 2018  8         231434.0
# Name: Gross, dtype: float64

# %% [markdown]
# ## The graphs and the series above both point to the same conclusion.

# %% [markdown]
# ## December is by far the best month to release a movie. As it has had the highest median sales in 4 of the last 6 years. Granted due to the holiday season this is  expected.
# ## However, It is also apparent through the visualizations and table, that November and Febraury also sell very well.
# ## That also make sense as both months are near the holiday season as well.
# ## After those I would rank October and August as the best choices.
# ## I would presume this is because both months are near  the summer season.
